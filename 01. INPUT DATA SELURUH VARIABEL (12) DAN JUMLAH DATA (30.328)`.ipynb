# %% [markdown]
# ##**FINAL ANALISA CLUSTER EVAN PAKAI FILE "SIDANG 19 MEI 2025.csv" SESUAI VARIABEL** **(SETELAH SIDANG 19 MEI 2025)**

# %% [markdown]
# >## **INPUT DATA SELURUH VARIABEL (12) DAN JUMLAH DATA (30.328)**`

# %%
from google.colab import drive
import pandas as pd
import os

# Mount Google Drive
drive.mount('/content/drive')

# Tentukan folder tujuan di Google Drive
save_path = '/content/drive/MyDrive/Colab Notebooks/TESIS/REVISI AFTER SEMINAR HASIL/'
os.makedirs(save_path, exist_ok=True)

# Membaca file CSV dengan pandas
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/TESIS/REVISI AFTER SEMINAR HASIL/SIDANG 19 MEI 2025.csv")

# Menampilkan beberapa baris pertama dari data
data.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                Kecamatan      Desa  Jumlah_Anggota_Rumah_Tangga  Status_Lahan  \
# 0  Mentaya Hilir Selatan  Sebamban                            4             1
# 1  Mentaya Hilir Selatan  Sebamban                            2             1
# 2  Mentaya Hilir Selatan  Sebamban                            4             1
# 3  Mentaya Hilir Selatan  Sebamban                            4             1
# 4  Mentaya Hilir Selatan  Sebamban                            4             3
#
#    Sumber_Air  Akses_Air_Minum  Fasilitas_BAB  Kloset  Fasilitas_Buang_Tinja  \
# 0          11                3              2       3                      4
# 1          11                3              2       3                      4
# 2          11                3              4       4                      4
# 3          11                3              1       2                      1
# 4          11                3              2       3                      4
#
#    Jumlah_Sepeda  Jumlah_Perahu  Aset_Tak_Bergerak_Rumah_Tangga  \
# 0              2              4                               1
# 1              2              4                               1
# 2              2              4                               1
# 3              1              4                               1
# 4              1              4                               2
#
#    Jumlah_Rumah_Lain  Status_Kesejahteraan_Rumah_Tangga
# 0                  4                                  4
# 1                  4                                  5
# 2                  4                                  4
# 3                  4                                  5
# 4                  4                                  3
